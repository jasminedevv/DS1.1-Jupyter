# %%
import pandas as pd

import seaborn as sns

df = pd.read_csv("./datasets/2016.csv")

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df
# Out:
#                timestamp  track  satisfaction  pacing location  week  \
# 0    2016-07-22 12:52:43   Apps           4.0     3.0       SV   5.0
# 1    2016-07-22 12:53:47   Apps           5.0     3.0       SV   5.0
# 2    2016-07-23 14:14:16   Apps           3.0     3.0       SV   5.0
# 3    2016-07-22 14:37:17   Apps           2.0     3.0       SV   5.0
# 4    2016-07-22 12:49:36  Games           4.0     3.0       SV   5.0
# 5    2016-07-22 12:50:23  Games           4.0     3.0       SV   5.0
# 6    2016-07-22 12:53:36   Apps           5.0     3.0       SV   5.0
# 7    2016-07-22 13:11:42   Apps           3.0     3.0       SV   5.0
# 8    2016-07-22 14:03:30   Apps           5.0     3.0       SV   5.0
# 9    2016-07-22 14:25:23   Apps           4.0     4.0       SV   5.0
# 10   2016-07-22 14:54:14   Apps           4.0     3.0       SV   5.0
# 11   2016-07-22 14:26:04   Apps           5.0     3.0       SV   5.0
# 12   2016-07-22 12:45:30  Intro           4.0     4.0       SV   5.0
# ...

# %%
df.describe()
# Out:
#        satisfaction      pacing        week
# count    926.000000  926.000000  926.000000
# mean       4.190065    3.282937    3.601512
# std        0.792225    0.680120    2.095544
# min        1.000000    1.000000    1.000000
# 25%        4.000000    3.000000    2.000000
# 50%        4.000000    3.000000    3.000000
# 75%        5.000000    4.000000    5.000000
# max        5.000000    5.000000    7.000000

# %% [markdown]
# # Overall way more Promoters than Passives and Detractors

# %%
sns.countplot(x="nps", palette="spring", data=df)
