# %%
import numpy as np 
import pandas as pd 

df = pd.read_csv('../datasets/titanic.csv')

# %%
df[["Ticket", "Sex"]]
# Out:
#                Ticket     Sex
# 0           A/5 21171    male
# 1            PC 17599  female
# 2    STON/O2. 3101282  female
# 3              113803  female
# 4              373450    male
# 5              330877    male
# 6               17463    male
# 7              349909    male
# 8              347742  female
# 9              237736  female
# 10            PP 9549  female
# 11             113783  female
# 12          A/5. 2151    male
# 13             347082    male
# 14             350406  female
# 15             248706  female
# 16             382652    male
# 17             244373    male
# 18             345763  female
# 19               2649  female
# 20             239865    male
# 21             248698    male
# 22             330923  female
# 23             113788    male
# 24             349909  female
# 25             347077  female
# 26               2631    male
# 27              19950    male
# 28             330959  female
# 29             349216    male
# ...

# %%
plt = df['Age'].hist(bins=16)
plt

# %%
df[ (df["Sex"] == "male") ].Age.hist(bins = 16)
df[ (df["Sex"] == "female") ].Age.hist(bins = 16)

# %%
df["Age"].isna().sum()
# Out:
# 177

# %%
def numeric_gender(sex):
    if sex == 'female':
        return 0
    if sex == 'male':
        return 1
    
df["Gender"] = df["Sex"].apply(numeric_gender)

# %%
df.shape
# Out:
# (891, 13)

# %%
df['Age'].plot.box()

# %%
df["Age"].dropna().values
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
import seaborn as sns
sns.countplot(x="Embarked", palette="spring", data=df)

# %%
sns.countplot(x="Sex", palette="pastel", data=df)

# %%
df[df["Embarked"] == 'C'].groupby('Sex')['Age'].plot(bins=16, kind="hist", legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df["Embarked"] == 'C'].groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64

# %%
df.groupby('Sex')['Age'].agg(np.median)
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
sns.regplot("Age", "Fare", fit_reg=False, data=df)

# %%
df.plot.scatter(x="Age", y="Fare")

# %%
men = df[df["Sex"] == "male"]

# %%
sns.countplot(x="Sex", hue="Pclass", data=df)

# %%
sns.countplot(x="Pclass", hue="Sex", data=df[df["Sex"] == "male"], palette="winter", alpha=0.8)
sns.countplot(x="Pclass", hue="Sex", data=df[df["Sex"] == "female"], palette="spring", alpha=0.8)

# %%
df.groupby(['Sex', 'Survived'])["Pclass"]

# %%
pd.crosstab(df['Sex'], df['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
pd.crosstab(df['Sex'], df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
sns.heatmap(pd.crosstab(df['Sex'], df['Embarked'], normalize='index'), cmap='RdBu_r', annot=True)

# %%
ls_fare = df['Fare'].dropna().values

# %%
import matplotlib.pyplot as plt
df['Fare'].hist(bins=16)
plt.show()

# %%
df['Fare'].hist(cumulative=True, density=True)

# %%
# get the mean
ls_fare.mean()
# calculate the percentage relative to total passengers
bargainers_percent = int(bargainers_num / len(ls_fare) * 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
# get how many people paid less than that
bargainers_num = df[df['Fare'] <= np.mean(ls_fare)]
bargainers_num['Fare'].sum()
# Out:
# 9351.9367

# %%
np.percentile(ls_fare, 75)
# Out:
# 31.0

# %%
np.percentile(ls_fare, 100)
# Out:
# 512.3292

# %%
# get all passengers who payed over $100
rich_and_alive = len(df[(df.Fare > 100) & (df.Survived == 1)])
rich_and_alive
total = len(df)
# Out:
# 891
