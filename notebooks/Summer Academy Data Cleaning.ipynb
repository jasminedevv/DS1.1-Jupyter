# %%
import pandas as pd

import glob, os

data_root = "../datasets/surveys/2016/"
normal_data = "Anon*.csv"
outlier_data = "week8.csv"

# %%
(data_root + normal_data)
FILENAMES = glob.glob(data_root + normal_data)

# %%
FILENAMES
# Out:
# ['../datasets/surveys/2016/Anon_Week_5_Feedback_-_SV.csv',
#  '../datasets/surveys/2016/Anon_Week_3_Feedback_-_LA.csv',
#  '../datasets/surveys/2016/Anon_Week_2_Feedback_-_SF.csv',
#  '../datasets/surveys/2016/Anon_Week_6_Feedback_-_Tokyo.csv',
#  '../datasets/surveys/2016/Anon_Week_3_Feedback_-_NY.csv',
#  '../datasets/surveys/2016/Anon_Week_3_Feedback_-_SF.csv',
#  '../datasets/surveys/2016/Anon_Week_4_Feedback_-_LA.csv',
#  '../datasets/surveys/2016/Anon_Week_6_Feedback_-_Taipei.csv',
#  '../datasets/surveys/2016/Anon_Week_2_Feedback_-_SG.csv',
#  '../datasets/surveys/2016/Anon_Week_7_Feedback_-_SV.csv',
#  '../datasets/surveys/2016/Anon_Week_7_Feedback_-_SF.csv',
#  '../datasets/surveys/2016/Anon_Week_7_Feedback_-_Taipei.csv',
#  '../datasets/surveys/2016/Anon_Week_2_Feedback_-_SV.csv',
#  '../datasets/surveys/2016/Anon_Week_6_Feedback_-_SG.csv',
#  '../datasets/surveys/2016/Anon_Week_2_Feedback_-_NY.csv',
#  '../datasets/surveys/2016/Anon_Week_7_Feedback_-_NY.csv',
# ...

# %%
df8 = pd.read_csv(data_root + outlier_data)

# %%
df8
# Out:
#                                    #  \
# 0   00b836bda84e6bdbe780af97e249e59f
# 1   39dde6dc0e1e375845d756fc7e39fc5f
# 2   5e56b9de91670b308cb98dd2848b8739
# 3   641081d05785b47a0f17448625da0d49
# 4   c29bdd4f5678d78b450f4494e0f53c8c
# 5   9030d8a662b39b519b2b685834413d66
# 6   1c07190c7caa72bf6b59cea48e1a4a97
# 7   27a63d6c24710feb52c0cfdef7e01175
# 8   b47b95f84547d8347119de1da5faa46d
# 9   828fafa477484f61d2ca5930fe99ad46
# 10  7d70f1e30217d867f3c0f961462d8ae8
# 11  65bd071ab808290560e7d11c09f56796
# 12  d66976d012b4c8a5c708f1a438605488
# 13  9db748a8e0d5789cb3a5fcb27fc59083
# 14  5ee2a5d8e87fd5790906f7b004963e14
# 15  9826290f1bf2fd4c105857e2af933ffe
# 16  ea85e7c699751b5993776ef16db0b1d9
# 17  58cb61ce774b116d87e3888d4c1babf1
# 18  a08ef61cfa87d1ba00c691de4a55f4c2
# 19  630fd265cdb8308b60b4b59351690f0a
# 20  2f7303a7ac0943b341d02678b085688e
# 21  785568c94d73aa0fad4493ee79fa3974
# 22  fe02b118aea0ef15ccd06e6f7e6209f4
# 23  6e2c750a71613e3fd7d5f425320cc750
# ...

# %%
dfs = [pd.read_csv(f) for f in FILENAMES]

# %% [markdown]
# # Grab unique columns from all 2016 DataFrames and save to set

# %%
unique_cols = set()

for df in dfs:
    unique_cols.update(df.columns)
    
# Add new columns to all 2016 DataFrames
unique_cols.update(["Week", "Location"])

# %%
unique_cols
# Out:
# {'How well are the tutorials paced?',
#  'How well is the schedule paced?',
#  'How would you rate your overall satisfaction with the Summer Academy this week?',
#  'Location',
#  'Timestamp',
#  'Unnamed: 0',
#  'Week',
#  'What track are you in?'}

# %%
col_true_names = {
    'How well are the tutorials paced?': 'pacing',
    'How well is the schedule paced?':'pacing',
    'How would you rate your overall satisfaction with the Summer Academy this week?': 'satisfaction',
    'What track are you in?':'track',
    'Timestamp':'timestamp',
    'Unnamed: 0': 'timestamp',
    'Week':'week',
    'Location': 'location'}

# %%
dfs = [pd.read_csv(f) for f in FILENAMES]

# dfs = list()
# for index, filename in enumerate(FILENAMES):
#     dfs.append(pd.read_csv(filename))
    
dfs[0]
# Out:
#              Timestamp What track are you in?  \
# 0   7/22/2016 12:52:43                   Apps
# 1   7/22/2016 12:53:47                   Apps
# 2   7/23/2016 14:14:16                   Apps
# 3   7/22/2016 14:37:17                   Apps
# 4   7/22/2016 12:49:36                  Games
# 5   7/22/2016 12:50:23                  Games
# 6   7/22/2016 12:53:36                   Apps
# 7   7/22/2016 13:11:42                   Apps
# 8   7/22/2016 14:03:30                   Apps
# 9   7/22/2016 14:25:23                   Apps
# 10  7/22/2016 14:54:14                   Apps
# 11  7/22/2016 14:26:04                   Apps
# 12  7/22/2016 12:45:30                  Intro
# 13  7/22/2016 14:25:54                   Apps
# 14  7/22/2016 12:47:59                   Apps
# 15  7/22/2016 16:21:04                   Apps
# 16  7/22/2016 14:25:46                   Apps
# 17  7/22/2016 15:53:14                   Apps
# 18  7/22/2016 18:00:51                   Apps
# ...

# %%
df.columns[0]
# Out:
# 'What track are you in?'

# %%
new_ds_set= []

for index, df in enumerate(dfs):
#       Rename the header to reflect dictionary
    new_name= df.rename(columns=col_true_names)
    new_ds_set.append(new_name)
    
#       input new colume with filename data
    fileparts = FILENAMES[index].split("_")
    week_num =  int(fileparts[2])
    location = fileparts[5].split(".")[1][:-4]
#     Declare new 
    df["Location"] =  location
    df["Week"] = week_num

new_ds_set
# Out:
# [             timestamp  track  satisfaction  pacing
#  0   7/22/2016 12:52:43   Apps             4       3
#  1   7/22/2016 12:53:47   Apps             5       3
#  2   7/23/2016 14:14:16   Apps             3       3
#  3   7/22/2016 14:37:17   Apps             2       3
#  4   7/22/2016 12:49:36  Games             4       3
#  5   7/22/2016 12:50:23  Games             4       3
#  6   7/22/2016 12:53:36   Apps             5       3
#  7   7/22/2016 13:11:42   Apps             3       3
#  8   7/22/2016 14:03:30   Apps             5       3
#  9   7/22/2016 14:25:23   Apps             4       4
#  10  7/22/2016 14:54:14   Apps             4       3
#  11  7/22/2016 14:26:04   Apps             5       3
#  12  7/22/2016 12:45:30  Intro             4       4
#  13  7/22/2016 14:25:54   Apps             5       3
#  14  7/22/2016 12:47:59   Apps             4       5
#  15  7/22/2016 16:21:04   Apps             2       2
#  16  7/22/2016 14:25:46   Apps             4       3
# ...

# %%
# meltable = list(dfs_set)
# melted = pd.melt(dfs_set)

# melted = pd.melt(new_ds_set[1], new_ds_set[2])
# melted

# new_ds_set.melt()
new_ds_set[1]
# Out:
#            timestamp  satisfaction  pacing
# 0  7/8/2016 10:31:27             4       2
# 1  7/8/2016 13:45:52             4       4
# 2  7/8/2016 13:47:42             4       3
# 3  7/8/2016 13:47:59             4       3
# 4  7/8/2016 14:12:24             4       3
# 5  7/8/2016 14:13:39             5       4

# %% [markdown]
# # Some Helpful Docs
# - [Renaming columns](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html)
# - [Drop columns](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)
# - [Add columns](https://erikrood.com/Python_References/add_new_col_df_default_value_final.html)
# - [np.nan](https://www.numpy.org/devdocs/reference/constants.html#numpy.NAN)

# %%
from functools import reduce
# concatenates all the dfs in new_df_set

def SA_normalizer(df, cols_list, new_names):
    """takes a dataframe, renames colums, drops columns it doesn't need, and adds NaN filled ones.
    Arguments:
        1. df: the dataframe to normalize
        2. cols_list: list of columns the df should have by the end
        3. new_names: dict of possible column names 
    Steps:
        1. renames columns: 
        2. removes unnecessary columns: 
        3. adds necessary columns filled with NaN
    TODO: make more generic by adding arguments corresponding to the exact columns you want
    """
    # rename columns
    
    # remove unnecessary columns
    
    # adds nonexistent columns 

def normalize_dfs(dfs, normalize):
    """takes a list of dataframes, applies the normalizer to each one and then concats them all into a big dataframe"""
    big_df = pd.DataFrame()
    for df in dfs:
        df = normalize(df)
        pd.concat([df, big_df])
    return big_df
        

# mother_df = reduce((lambda self, target: pd.concat(self,target)), new_ds_set)
mother_df = concat_list_of_dfs(new_ds_set)
type(new_ds_set)
mother_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
