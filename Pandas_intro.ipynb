# %%
import pandas as pd

df = pd.DataFrame(data= {'name':['john', 'mary', 'peter','jeff','bill', 'lisa'], 'age':[23, 78, 22, 19, 45, 33], 
                         'state': ['iowa', 'dc', 'california', 'texas', 'washington', 'dc'], 'num_children': [2, 2, 0, 1, 2, 1],
                        'num_pets' : [0, 4, 0, 5, 0, 0]})

# %%
df
# Out:
#     name  age       state  num_children  num_pets
# 0   john   23        iowa             2         0
# 1   mary   78          dc             2         4
# 2  peter   22  california             0         0
# 3   jeff   19       texas             1         5
# 4   bill   45  washington             2         0
# 5   lisa   33          dc             1         0

# %%
df.columns
# Out:
# Index(['name', 'age', 'state', 'num_children', 'num_pets'], dtype='object')

# %%
df[['name', 'age']]
# Out:
#     name  age
# 0   john   23
# 1   mary   78
# 2  peter   22
# 3   jeff   19
# 4   bill   45
# 5   lisa   33

# %%
df.loc[2:4, 'name']
# Out:
# 2    peter
# 3     jeff
# 4     bill
# Name: name, dtype: object

# %%
df.iloc[:2]
# Out:
#    name  age state  num_children  num_pets
# 0  john   23  iowa             2         0
# 1  mary   78    dc             2         4

# %%
df.iloc[:-2]
# Out:
#     name  age       state  num_children  num_pets
# 0   john   23        iowa             2         0
# 1   mary   78          dc             2         4
# 2  peter   22  california             0         0
# 3   jeff   19       texas             1         5

# %%
df[df.num_children < df.num_pets]
# Out:
#    name  age  state  num_children  num_pets
# 1  mary   78     dc             2         4
# 3  jeff   19  texas             1         5

# %%
df[(df.num_pets > 0) & (df.age >= 40)]
# Out:
#    name  age state  num_children  num_pets
# 1  mary   78    dc             2         4

# %%
df
# Out:
#     name  age       state  num_children  num_pets
# 0   john   23        iowa             2         0
# 1   mary   78          dc             2         4
# 2  peter   22  california             0         0
# 3   jeff   19       texas             1         5
# 4   bill   45  washington             2         0
# 5   lisa   33          dc             1         0

# %%
df.drop(columns=["age", "num_children"])
# Out:
#     name       state  num_pets
# 0   john        iowa         0
# 1   mary          dc         4
# 2  peter  california         0
# 3   jeff       texas         5
# 4   bill  washington         0
# 5   lisa          dc         0

# %%
df.mean()
# Out:
# age             36.666667
# num_children     1.333333
# num_pets         1.500000
# dtype: float64

# %%
df.describe()
# Out:
#              age  num_children  num_pets
# count   6.000000      6.000000  6.000000
# mean   36.666667      1.333333  1.500000
# std    22.384518      0.816497  2.345208
# min    19.000000      0.000000  0.000000
# 25%    22.250000      1.000000  0.000000
# 50%    28.000000      1.500000  0.000000
# 75%    42.000000      2.000000  3.000000
# max    78.000000      2.000000  5.000000

# %%
df[:2].describe()
# Out:
#                 age  num_children  num_pets      kash
# count      2.000000           2.0  2.000000  2.000000
# mean   12928.000000           2.0  2.000000  0.500000
# std     9956.063479           0.0  2.828427  0.707107
# min     5888.000000           2.0  0.000000  0.000000
# 25%     9408.000000           2.0  1.000000  0.250000
# 50%    12928.000000           2.0  2.000000  0.500000
# 75%    16448.000000           2.0  3.000000  0.750000
# max    19968.000000           2.0  4.000000  1.000000

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
type(df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
dfa = df.iloc[:]
dfa["age"] = dfa[["age"]].apply(lambda value: value*2)
dfa
# Out:
#     name    age       state  num_children  num_pets
# 0   john   46.0        iowa             2         0
# 1   mary  156.0          dc             2         4
# 2  peter   44.0  california             0         0
# 3   jeff   38.0       texas             1         5
# 4   bill   90.0  washington             2         0
# 5   lisa   66.0          dc             1         0

# %%
df.sort_values("age")
# Out:
#     name    age       state  num_children  num_pets
# 3   jeff   38.0       texas             1         5
# 2  peter   44.0  california             0         0
# 0   john   46.0        iowa             2         0
# 5   lisa   66.0          dc             1         0
# 4   bill   90.0  washington             2         0
# 1   mary  156.0          dc             2         4

# %%
df
# Out:
#     name   age       state  num_children  num_pets
# 0   john  23.0        iowa             2         0
# 1   mary  78.0          dc             2         4
# 2  peter  22.0  california             0         0
# 3   jeff  19.0       texas             1         5
# 4   bill  45.0  washington             2         0
# 5   lisa  33.0          dc             1         0

# %%
df[df.name.str.startswith('j')]
# Out:
#    name   age  state  num_children  num_pets
# 0  john  23.0   iowa             2         0
# 3  jeff  19.0  texas             1         5

# %%
from collections import OrderedDict
from pandas import DataFrame
import pandas as pd
import numpy as np

table = OrderedDict((
    ("Item", ['Item0', 'Item0', 'Item1', 'Item1']),
    ('CType',['Gold', 'Bronze', 'Gold', 'Silver']),
    ('USD',  ['1$', '2$', '3$', '4$']),
    ('EU',   ['1€', '2€', '3€', '4€'])
))
d = DataFrame(table)

# %%
d
# Out:
#     Item   CType USD  EU
# 0  Item0    Gold  1$  1€
# 1  Item0  Bronze  2$  2€
# 2  Item1    Gold  3$  3€
# 3  Item1  Silver  4$  4€

# %%
p = d.pivot(index='Item', columns='CType', values="USD")

# %%
p
# Out:
# CType Bronze Gold Silver
# Item
# Item0     2$   1$    NaN
# Item1    NaN   3$     4$
